# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/Textembedding_using_Langchain_Openai/blob/main/Textembedding_using_Langchain_Openai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain

# %%
# !pip install Openai

# %%
import os
os.environ['OPENAI_API_KEY']='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'

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embedding=OpenAIEmbeddings()

# %%
embedding.embed_query('hey buddy')
# Out:
# [-0.02059866115450859,
#  -0.009346754290163517,
#  0.0015151714906096458,
#  -0.03334655985236168,
#  -0.02389751560986042,
#  0.014793699607253075,
#  -0.011021753773093224,
#  -0.018066981807351112,
#  -0.012198089621961117,
#  -0.005526859778910875,
#  0.01983148604631424,
#  -0.023795224726200104,
#  -0.00857318565249443,
#  0.0037783391308039427,
#  0.007595036644488573,
#  -0.026518696919083595,
#  0.03531564399600029,
#  -0.010708490386605263,
#  0.01819484494626522,
#  -0.004788453225046396,
#  -0.0038326806388795376,
#  -0.000844692112877965,
#  -0.004388882778584957,
#  -0.016634920611977577,
#  -0.01554808858782053,
#  -0.014793699607253075,
#  0.006284445524215698,
#  -0.018079767003655434,
#  0.017197515815496445,
#  -0.02899923175573349,
#  0.030405720695853233,
#  0.02552136965095997,
#  -0.020342934876680374,
#  -0.00612461706623435,
#  -0.02887136861681938,
#  -0.023411637172102928,
#  -0.005172041244804859,
#  -0.009174139238893986,
#  0.019179385155439377,
# ...
